# %%
import pandas as pd
import numpy as np

# %%
name=['sohan','rohan','mohan','ram','sita','gita']

# %%
data=pd.DataFrame(name,columns=['name'])

# %%
data['hindi']=np.random.randint(1,50,6)

# %%
data
# Out:
#     name  hindi
# 0  sohan     46
# 1  rohan     23
# 2  mohan     11
# 3    ram     42
# 4   sita     42
# 5   gita     30

# %%
data['kannda']=np.random.randint(1,50,6)
data['english']=np.random.randint(1,50,6)
data['math']=np.random.randint(1,50,6)
data['java']=np.random.randint(1,50,6)
data['machine_learning']=np.random.randint(1,50,6)

# %%
data
# Out:
#     name  hindi  kannda  english  math  java  machine_learning
# 0  sohan     46      37       36    37    14                 1
# 1  rohan     23      24       37    23    44                 5
# 2  mohan     11      21       31    37    26                 3
# 3    ram     42      23       32    31    27                11
# 4   sita     42      35       22    22    20                48
# 5   gita     30      14       10    35    24                 7

# %%
data['total']=data.iloc[:,1:].sum(axis=1)

# %%
data
# Out:
#     name  hindi  kannda  english  math  java  machine_learning  total
# 0  sohan     46      37       36    37    14                 1    171
# 1  rohan     23      24       37    23    44                 5    156
# 2  mohan     11      21       31    37    26                 3    129
# 3    ram     42      23       32    31    27                11    166
# 4   sita     42      35       22    22    20                48    189
# 5   gita     30      14       10    35    24                 7    120

# %%
# data=data.rename({"hindi":"indi"},inplace=True)

# %%
data
# Out:
#     name  hindi  kannda  english  math  java  machine_learning  total
# 0  sohan     46      37       36    37    14                 1    171
# 1  rohan     23      24       37    23    44                 5    156
# 2  mohan     11      21       31    37    26                 3    129
# 3    ram     42      23       32    31    27                11    166
# 4   sita     42      35       22    22    20                48    189
# 5   gita     30      14       10    35    24                 7    120

# %%
# data.append({'name':'rita','hindi':43,'kannda':12,'english':10,'math':11,'java':13,'machine_learning':13},ignore_index=True)

# %%
l={'name':'rita','hindi':43,'kannda':12,'english':10,'math':11,'java':13,'machine_learning':13}

# %%
data.loc[len(data)]=l

# %%
len(data)
# Out:
# 7

# %%
data
# Out:
#     name  hindi  kannda  english  math  java  machine_learning  total
# 0  sohan     46      37       36    37    14                 1  342.0
# 1  rohan     23      24       37    23    44                 5  312.0
# 2  mohan     11      21       31    37    26                 3  258.0
# 3    ram     42      23       32    31    27                11  332.0
# 4   sita     42      35       22    22    20                48  378.0
# 5   gita     30      14       10    35    24                 7  240.0
# 6   rita     43      12       10    11    13                13  102.0

# %%
data['failed_count']=(data.iloc[:,1:6]<18).sum(axis=1)

# %%
data
# Out:
#     name  hindi  kannda  english  math  java  machine_learning  total  \
# 0  sohan     46      37       36    37    14                 1  342.0
# 1  rohan     23      24       37    23    44                 5  312.0
# 2  mohan     11      21       31    37    26                 3  258.0
# 3    ram     42      23       32    31    27                11  332.0
# 4   sita     42      35       22    22    20                48  378.0
# 5   gita     30      14       10    35    24                 7  240.0
# 6   rita     43      12       10    11    13                13  102.0
#
#    failed_count
# 0             1
# 1             0
# 2             1
# 3             0
# 4             0
# 5             2
# 6             4

# %%
data['pass/fail']='pass'

# %%
data
# Out:
#     name  hindi  kannda  english  math  java  machine_learning  total  \
# 0  sohan     46      37       36    37    14                 1  342.0
# 1  rohan     23      24       37    23    44                 5  312.0
# 2  mohan     11      21       31    37    26                 3  258.0
# 3    ram     42      23       32    31    27                11  332.0
# 4   sita     42      35       22    22    20                48  378.0
# 5   gita     30      14       10    35    24                 7  240.0
# 6   rita     43      12       10    11    13                13  102.0
#
#    failed_count pass/fail
# 0             1      pass
# 1             0      pass
# 2             1      pass
# 3             0      pass
# 4             0      pass
# 5             2      pass
# 6             4      pass

# %%
data.loc[data.loc[:,'failed_count']>=4,'pass/fail']='fail'

# %%
data
# Out:
#     name  hindi  kannda  english  math  java  machine_learning  total  \
# 0  sohan     46      37       36    37    14                 1  342.0
# 1  rohan     23      24       37    23    44                 5  312.0
# 2  mohan     11      21       31    37    26                 3  258.0
# 3    ram     42      23       32    31    27                11  332.0
# 4   sita     42      35       22    22    20                48  378.0
# 5   gita     30      14       10    35    24                 7  240.0
# 6   rita     43      12       10    11    13                13  102.0
#
#    failed_count pass/fail
# 0             1      pass
# 1             0      pass
# 2             1      pass
# 3             0      pass
# 4             0      pass
# 5             2      pass
# 6             4      fail
